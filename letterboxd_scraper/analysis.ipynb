# %%
import pandas as pd
import numpy as np

# %%
films = pd.read_csv('./films-jospam.csv')

# %%
films
# Out:
#                                                    url  \
# 0    https://letterboxd.com/film/black-panther-waka...
# 1    https://letterboxd.com/film/chip-n-dale-rescue...
# 2    https://letterboxd.com/film/thor-love-and-thun...
# 3    https://letterboxd.com/film/everything-everywh...
# 4    https://letterboxd.com/film/spider-man-no-way-...
# ..                                                 ...
# 431  https://letterboxd.com/film/star-wars-the-last...
# 432  https://letterboxd.com/film/star-wars-the-rise...
# 433  https://letterboxd.com/film/space-jam-a-new-le...
# 434  https://letterboxd.com/film/my-hero-academia-h...
# 435     https://letterboxd.com/film/the-suicide-squad/
#
#                                  title  year  length (mins) rating  \
# 0       Black Panther: Wakanda Forever  2022            162    4.0
# 1         Chip 'n Dale: Rescue Rangers  2022             99    3.0
# 2               Thor: Love and Thunder  2022            119    4.0
# ...

# %% [markdown]
# Number of Films

# %%
number_films = films.shape[0]
number_films
# Out:
# 436

# %% [markdown]
# Total Hours Watched

# %%
length_minutes = films['length (mins)'].sum()
length_minutes
# Out:
# 50888

# %%
length_hours = int(length_minutes / 60)
length_hours
# Out:
# 848

# %% [markdown]
# Difference Average vs Personal Rating

# %%
films['rating'] = films['rating'].replace(['None'],100)
films
# Out:
#                                                    url  \
# 0    https://letterboxd.com/film/black-panther-waka...
# 1    https://letterboxd.com/film/chip-n-dale-rescue...
# 2    https://letterboxd.com/film/thor-love-and-thun...
# 3    https://letterboxd.com/film/everything-everywh...
# 4    https://letterboxd.com/film/spider-man-no-way-...
# ..                                                 ...
# 431  https://letterboxd.com/film/star-wars-the-last...
# 432  https://letterboxd.com/film/star-wars-the-rise...
# 433  https://letterboxd.com/film/space-jam-a-new-le...
# 434  https://letterboxd.com/film/my-hero-academia-h...
# 435     https://letterboxd.com/film/the-suicide-squad/
#
#                                  title  year  length (mins) rating  \
# 0       Black Panther: Wakanda Forever  2022            162    4.0
# 1         Chip 'n Dale: Rescue Rangers  2022             99    3.0
# 2               Thor: Love and Thunder  2022            119    4.0
# ...

# %%
films.to_csv('films.csv')

# %%
films.insert(loc=6, column='diff_rating', value= 0)

# %%
films['diff_rating'] = pd.to_numeric(films['rating'], errors='coerce') - films['average_rating']
films
# Out:
#                                                    url  \
# 0    https://letterboxd.com/film/black-panther-waka...
# 1    https://letterboxd.com/film/chip-n-dale-rescue...
# 2    https://letterboxd.com/film/thor-love-and-thun...
# 3    https://letterboxd.com/film/everything-everywh...
# 4    https://letterboxd.com/film/spider-man-no-way-...
# ..                                                 ...
# 431  https://letterboxd.com/film/star-wars-the-last...
# 432  https://letterboxd.com/film/star-wars-the-rise...
# 433  https://letterboxd.com/film/space-jam-a-new-le...
# 434  https://letterboxd.com/film/my-hero-academia-h...
# 435     https://letterboxd.com/film/the-suicide-squad/
#
#                                  title  year  length (mins) rating  \
# 0       Black Panther: Wakanda Forever  2022            162    4.0
# 1         Chip 'n Dale: Rescue Rangers  2022             99    3.0
# 2               Thor: Love and Thunder  2022            119    4.0
# ...

# %% [markdown]
# Films Watched Per Year

# %%
films.sort_values(by=['year'], ascending=True).groupby('year').count()['url']
# Out:
# year
# 1946     1
# 1968     1
# 1977     1
# 1979     1
# 1980     1
# 1982     1
# 1983     1
# 1984     2
# 1985     1
# 1986     2
# 1987     2
# 1988     4
# 1989     2
# 1990     3
# 1991     2
# 1992     2
# 1993     5
# 1994     3
# 1995     3
# 1996     1
# 1997     5
# 1998     5
# 1999     7
# 2000     7
# 2001    10
# 2002    13
# 2003     8
# 2004    16
# 2005    10
# 2006    13
# 2007    12
# 2008    11
# 2009    21
# 2010    16
# 2011    15
# 2012    20
# 2013    30
# 2014    26
# 2015    21
# 2016    26
# 2017    30
# 2018    18
# 2019    27
# 2020    12
# 2021    11
# 2022     7
# Name: url, dtype: int64

# %% [markdown]
# Average Rating per Year

# %%
films['rating'] = films['rating'].astype(float)

# %%
films[films['rating'] <= 5].groupby('year')['rating'].mean()
# Out:
# year
# 1946    4.000000
# 1968    3.500000
# 1979    5.000000
# 1982    4.000000
# 1984    3.750000
# 1986    4.000000
# 1987    3.250000
# 1988    4.250000
# 1989    5.000000
# 1990    3.000000
# 1991    4.500000
# 1992    2.750000
# 1993    4.125000
# 1994    4.166667
# 1995    3.833333
# 1996    4.000000
# 1997    3.750000
# 1998    3.500000
# 1999    4.375000
# 2000    4.166667
# 2001    3.785714
# 2002    3.571429
# 2003    3.750000
# 2004    3.833333
# 2005    3.500000
# 2006    3.111111
# 2007    3.125000
# 2008    4.083333
# 2009    3.538462
# 2010    3.642857
# 2011    4.000000
# 2012    3.541667
# 2013    3.600000
# 2014    3.933333
# 2015    3.291667
# 2016    3.823529
# 2017    3.333333
# 2018    3.416667
# 2019    3.500000
# 2020    3.500000
# 2021    3.954545
# 2022    3.785714
# Name: rating, dtype: float64

# %% [markdown]
# Films Watched Per Language

# %%
films.groupby('original_language').count()['url']
# Out:
# original_language
# English      354
# French         4
# Hindi          1
# Japanese      65
# Korean         5
# Norwegian      1
# Spanish        6
# Name: url, dtype: int64

# %% [markdown]
# Top 10 Films Rated higher than average

# %%
films[films['diff_rating'] < 5].sort_values(by=['diff_rating'], ascending=False).iloc[0:10]
# Out:
#                                                    url  \
# 433  https://letterboxd.com/film/space-jam-a-new-le...
# 354            https://letterboxd.com/film/prometheus/
# 328       https://letterboxd.com/film/kung-fu-panda-2/
# 365  https://letterboxd.com/film/the-hunger-games-m...
# 385     https://letterboxd.com/film/nocturnal-animals/
# 310             https://letterboxd.com/film/bee-movie/
# 32             https://letterboxd.com/film/the-grinch/
# 196          https://letterboxd.com/film/spider-man-2/
# 72      https://letterboxd.com/film/the-good-dinosaur/
# 176  https://letterboxd.com/film/scott-pilgrim-vs-t...
#
#                                      title  year  length (mins)  \
# 433                Space Jam: A New Legacy  2021            115
# 354                             Prometheus  2012            124
# 328                        Kung Fu Panda 2  2011             91
# 365  The Hunger Games: Mockingjay - Part 1  2014            123
# ...

# %% [markdown]
# Top 10 Films Rated lower than average

# %%
films[films['diff_rating'] < 5].sort_values(by=['diff_rating'], ascending=True).iloc[0:10]
# Out:
#                                                    url  \
# 304          https://letterboxd.com/film/paprika-2006/
# 316  https://letterboxd.com/film/live-free-or-die-h...
# 80             https://letterboxd.com/film/sinister-2/
# 68              https://letterboxd.com/film/3-idiotas/
# 100  https://letterboxd.com/film/a-good-day-to-die-...
# 284    https://letterboxd.com/film/a-walk-to-remember/
# 225              https://letterboxd.com/film/predator/
# 422     https://letterboxd.com/film/american-assassin/
# 42                https://letterboxd.com/film/promare/
# 346  https://letterboxd.com/film/the-amazing-spider...
#
#                       title  year  length (mins)  numeric_rating rating  \
# 304                 Paprika  2006             90             2.0    2.0
# 316   Live Free or Die Hard  2007            128             1.0    1.0
# 80               Sinister 2  2015             97             1.0    1.0
# ...

# %% [markdown]
# Splitting values into arrays

# %%
films_copy = films.copy()
films_copy['director'] = films_copy['director'].fillna("").apply(lambda x: x.split('/'))

# %%
films_copy['country'] = films_copy['country'].fillna("").apply(lambda x: x.split('/'))

# %%
films_copy['spoken_languages'] = films_copy['spoken_languages'].fillna("").apply(lambda x: x.split('/'))

# %%
films_copy.insert(loc=10, column='total_languages', value=films_copy['spoken_languages'].apply(lambda x: len(x)))

# %%
films_copy['studio'] = films_copy['studio'].fillna("").apply(lambda x: x.split('/'))

# %%
films_copy['genres'] = films_copy['genres'].fillna("").apply(lambda x: x.split('/'))

# %%
films_copy['themes'] = films_copy['themes'].fillna("").apply(lambda x: x.split('/'))

# %%
films_copy['composer'] = films_copy['composer'].fillna("").apply(lambda x: x.split('/'))

# %%
films_copy['cast'] = films_copy['cast'].fillna("").apply(lambda x: x.split('/'))

# %%
films = films_copy

# %% [markdown]
# Total Countries

# %%
films_copy = films.copy()

# %%
films_copy.explode('country')['country'].unique()
# Out:
# array(['USA', 'Japan', 'South Korea', 'France', 'UK', 'Canada', 'Austria',
#        'Germany', 'Czechia', 'New Zealand', 'China', 'Hungary', 'Spain',
#        'Mexico', 'Hong Kong', 'Thailand', 'Australia', 'India', '',
#        'Argentina', 'Bahamas', 'Denmark', 'Norway', 'Sweden', 'Belgium',
#        'South Africa', 'Netherlands', 'Ireland'], dtype=object)

# %%
films_copy.explode('country')['country'].unique().size
# Out:
# 28

# %%
films_copy.explode('country').groupby('country').count()['url'].sort_values(ascending=False).iloc[0:10]
# Out:
# country
# USA            351
# Japan           72
# UK              70
# Canada          15
# Germany         15
# France          13
# South Korea      8
# Mexico           7
# New Zealand      7
# China            6
# Name: url, dtype: int64

# %% [markdown]
# Top 10 More Languages spoken

# %%
films_copy.sort_values(by='total_languages', ascending=False).iloc[0:10]
# Out:
#                                                    url  \
# 426          https://letterboxd.com/film/drive-my-car/
# 422     https://letterboxd.com/film/american-assassin/
# 411     https://letterboxd.com/film/blade-runner-2049/
# 79       https://letterboxd.com/film/x-men-apocalypse/
# 347                https://letterboxd.com/film/my-way/
# 291  https://letterboxd.com/film/mission-impossible...
# 89           https://letterboxd.com/film/spectre-2015/
# 139     https://letterboxd.com/film/quantum-of-solace/
# 46   https://letterboxd.com/film/spider-man-far-fro...
# 207            https://letterboxd.com/film/crash-2004/
#
#                          title  year  length (mins) rating  average_rating  \
# 426               Drive My Car  2021            179    4.5            4.14
# 422          American Assassin  2017            112    1.5            2.77
# 411          Blade Runner 2049  2017            164    5.0            4.10
# ...

# %% [markdown]
# Themes & Genres

# %%
films_copy.explode('themes').groupby('themes').count()['url'].sort_values(ascending=False).iloc[0:10]
# Out:
# themes
# Epic heroes                                    173
# Monsters, aliens, sci-fi and the apocalypse    113
# High speed and special ops                      65
#                                                 60
# Epic history and literature                     51
# Crude humor and satire                          49
# Relationship comedy                             45
# Moving relationship stories                     39
# Underdogs and coming of age                     33
# War and historical adventure                    32
# Name: url, dtype: int64

# %%
films_copy.explode('genres').groupby('genres').count()['url'].sort_values(ascending=False).iloc[0:10]
# Out:
# genres
# adventure          209
# action             185
# animation          140
# drama              136
# science-fiction    134
# comedy             123
# fantasy            115
# family             106
# thriller            75
# romance             43
# Name: url, dtype: int64

# %% [markdown]
# Studios

# %%
films_copy.explode('studio').groupby('studio').count()['url'].sort_values(ascending=False).iloc[0:10]
# Out:
# studio
# Warner Bros. Pictures    53
# 20th Century Fox         44
# Walt Disney Pictures     33
# Paramount                28
# Marvel Studios           28
# Pixar                    24
# Columbia Pictures        23
# Studio Ghibli            22
# Universal Pictures       18
# DreamWorks Animation     17
# Name: url, dtype: int64

# %%
films_copy['rating'] = films_copy['rating'].astype(float)

# %%
films_copy[films_copy['rating'] <= 5].explode('studio').groupby('studio')['rating'].mean().sort_values(ascending=False).iloc[0:10]
# Out:
# studio
# Jersey Films                   5.0
# Red Granite Pictures           5.0
# T-Street Productions           5.0
# Michael De Luca Productions    5.0
# Knickerbocker Films            5.0
# Valhalla Motion Pictures       5.0
# Black Label Media              5.0
# EMJAG Productions              5.0
# Barunson E&A                   5.0
# Muse Productions               5.0
# Name: rating, dtype: float64

# %% [markdown]
# Composers

# %%
films_copy.explode('composer').groupby('composer').count()['url'].sort_values(ascending=False).iloc[0:10]
# Out:
# composer
# Hans Zimmer            26
# Michael Giacchino      18
#                        18
# John Williams          15
# John Powell            12
# Alan Silvestri         12
# Marco Beltrami         12
# Henry Jackman          12
# James Newton Howard    12
# Danny Elfman           11
# Name: url, dtype: int64

# %%
films_copy[films_copy['rating'] <= 5].explode('composer').groupby('composer')['rating'].mean().sort_values(ascending=False).iloc[0:10]
# Out:
# composer
# Michael Abels     5.0
# Jon Batiste       5.0
# Justin Hurwitz    5.0
# Nathan Johnson    5.0
# John Cale         5.0
# Owen Pallett      5.0
# Rafiq Bhatia      5.0
# Ian Chang         5.0
# Michio Mamiya     5.0
# Ryan Lott         5.0
# Name: rating, dtype: float64

# %% [markdown]
# Cast

# %%
films_copy.explode('cast').groupby('cast').count()['url'].sort_values(ascending=False).iloc[0:10]
# Out:
# cast
# Stan Lee              30
# Samuel L. Jackson     24
# John Ratzenberger     23
# Mickie McGowan        18
# Koichi Yamadera       17
# Bob Bergen            17
# Megumi Hayashibara    17
# Scarlett Johansson    16
# Sherry Lynn           15
# Robert Downey Jr.     15
# Name: url, dtype: int64

# %%
films_copy[films_copy['rating'] <= 5].explode('cast').groupby('cast')['rating'].mean().sort_values(ascending=False).iloc[0:10]
# Out:
# cast
# Robin Bartlett             5.0
# Rémy Bennett               5.0
# Edward J. Clare            5.0
# Sabrina Rattey             5.0
# Edward Kowalczyk           5.0
# Edward Linde-Lubaszenko    5.0
# Edward Norton              5.0
# Edwin H. Bravo             5.0
# S. Epatha Merkerson        5.0
# Efka Kvaraciejus           5.0
# Name: rating, dtype: float64

# %% [markdown]
# Directors

# %%
films_copy.explode('director')['director'].unique()
# Out:
# array(['Ryan Coogler', 'Akiva Schaffer', 'Taika Waititi',
#        'Daniel Scheinert', 'Daniel Kwan', 'Jon Watts', 'Byron Howard',
#        'Jared Bush', 'Jeff Fowler', 'Sam Raimi', 'Max Barbakow',
#        'Domee Shi', 'Lee Isaac Chung', 'Tim Hill', 'Harry Bradbeer',
#        'John Krasinski', 'Chloé Zhao', 'Pete Docter', 'Sam Levinson',
#        'Goro Miyazaki', 'Siân Heder', 'Junichi Sato',
#        'Tomotaka Shibayama', 'Cary Joji Fukunaga', 'Hideaki Anno',
#        'Dan Scanlon', 'Ron Howard', 'David Leitch', 'Brad Bird',
#        'Ryusuke Hamaguchi', 'Peyton Reed', 'Kenji Nagasaki',
#        'Christopher McQuarrie', 'Peter Farrelly', 'Rich Moore',
#        'Phil Johnston', 'Scott Mosier', 'Yarrow Cheney', 'Haruo Sotozaki',
#        'James Wan', 'Dean DeBlois', 'Rodney Rothman', 'Peter Ramsey',
#        'Bob Persichetti', 'Ryan Fleck', 'Anna Boden', 'David F. Sandberg',
#        'Anthony Russo', 'Joe Russo', 'Rob Letterman', 'Hiroyuki Imaishi',
# ...

# %%
films_copy.explode('director')['director'].unique().size
# Out:
# 293

# %%
films_copy.explode('director').groupby('director').count()['url'].sort_values(ascending=False).iloc[0:10]
# Out:
# director
# Hayao Miyazaki       10
# Kunihiko Yuyama       7
# Hideaki Anno          6
# Christopher Nolan     6
# Peter Jackson         6
# David Yates           6
# Ridley Scott          5
# Isao Takahata         5
# Quentin Tarantino     5
# John Lasseter         5
# Name: url, dtype: int64

# %%
films_copy[films_copy['rating'] <= 5].explode('director').groupby('director')['rating'].mean().sort_values(ascending=False).iloc[0:10]
# Out:
# director
# Damien Chazelle     5.0
# Peter Ramsey        5.0
# Sam Mendes          5.0
# Noah Baumbach       5.0
# Mary Harron         5.0
# Bob Persichetti     5.0
# Malcolm D. Lee      5.0
# Spike Jonze         5.0
# Rodney Rothman      5.0
# Kazuya Tsurumaki    5.0
# Name: rating, dtype: float64

# %% [markdown]
# End...?

# %%
films
# Out:
#                                                    url  \
# 0    https://letterboxd.com/film/black-panther-waka...
# 1    https://letterboxd.com/film/chip-n-dale-rescue...
# 2    https://letterboxd.com/film/thor-love-and-thun...
# 3    https://letterboxd.com/film/everything-everywh...
# 4    https://letterboxd.com/film/spider-man-no-way-...
# ..                                                 ...
# 431  https://letterboxd.com/film/star-wars-the-last...
# 432  https://letterboxd.com/film/star-wars-the-rise...
# 433  https://letterboxd.com/film/space-jam-a-new-le...
# 434  https://letterboxd.com/film/my-hero-academia-h...
# 435     https://letterboxd.com/film/the-suicide-squad/
#
#                                  title  year  length (mins)  rating  \
# 0       Black Panther: Wakanda Forever  2022            162     4.0
# 1         Chip 'n Dale: Rescue Rangers  2022             99     3.0
# 2               Thor: Love and Thunder  2022            119     4.0
# ...
